# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import logging
import sys

# %%
import nglview as nv
from rdkit import Chem
from rdkit.Chem import AllChem
m = Chem.AddHs(Chem.MolFromSmiles('COc1ccc2[C@H](O)[C@@H](COc2c1)N3CCC(O)(CC3)c4ccc(F)cc4'))
_ = AllChem.EmbedMultipleConfs(m, useExpTorsionAnglePrefs=True, useBasicKnowledge=True)
view = nv.show_rdkit(m)
view
# Out:
# NGLWidget()

# %%
try:
    import ppqm
except ModuleNotFoundError:
    import pathlib

    cwd = pathlib.Path().resolve().parent
    sys.path.append(str(cwd))
    import ppqm

# %%
m.GetNumConformers()
# Out:
# 10

# %%
coord = ppqm.chembridge.get_coordinates(m, confid=9)
view.set_coordinates({0: coord})

# %%
help(view)
# Out:
# Help on NGLWidget in module nglview.widget object:
#
# class NGLWidget(ipywidgets.widgets.domwidget.DOMWidget)
#  |  NGLWidget(*args, **kwargs)
#  |
#  |  Widget that can be inserted into the DOM
#  |
#  |  Method resolution order:
#  |      NGLWidget
#  |      ipywidgets.widgets.domwidget.DOMWidget
#  |      ipywidgets.widgets.widget.Widget
#  |      ipywidgets.widgets.widget.LoggingHasTraits
#  |      traitlets.traitlets.HasTraits
#  |      traitlets.traitlets.HasDescriptors
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, index)
#  |      return ComponentViewer
#  |
#  |  __init__(self, structure=None, representations=None, parameters=None, **kwargs)
#  |      Public constructor
#  |
#  |  __iter__(self)
#  |      return ComponentViewer
#  |
#  |  add_component(self, filename, **kwargs)
#  |      add component from file/trajectory/struture
#  |
#  |      Parameters
#  |      ----------
# ...

# %%
ppqm.jupyter.show_molobj(m)
# Out:
# interactive(children=(IntSlider(value=0, description='idx', max=9), Output()), _dom_classes=('widget-interact'…
# NGLWidget()
